# %%
import pandas as pd
import numpy as np
from sklearn.model_selection._validation import _num_samples
df = pd.read_csv('/Users/dylan/iCollections/桌面文件/jpx-tokyo-stock-exchange-prediction/reduced_train_files/reduced_stock_prices.csv')

# %%
_num_samples(df)
# Out:
# 2332531
