# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
prices = pd.read_csv('/Users/dylan/iCollections/桌面文件/jpx-tokyo-stock-exchange-prediction/code_JPX /data_preprocess/data_output/prices_update.csv')
options = pd.read_csv('/Users/dylan/iCollections/桌面文件/jpx-tokyo-stock-exchange-prediction/train_files/options.csv')
financials = pd.read_csv('/Users/dylan/iCollections/桌面文件/jpx-tokyo-stock-exchange-prediction/train_files/financials.csv')
trades = pd.read_csv('/Users/dylan/iCollections/桌面文件/jpx-tokyo-stock-exchange-prediction/train_files/trades.csv')
# Out:
# /var/folders/9l/qzgwttq17ps8lhfhrtgpdkx00000gn/T/ipykernel_78506/1425027391.py:2: DtypeWarning: Columns (7,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   options = pd.read_csv('/Users/dylan/iCollections/桌面文件/jpx-tokyo-stock-exchange-prediction/train_files/options.csv')
# /var/folders/9l/qzgwttq17ps8lhfhrtgpdkx00000gn/T/ipykernel_78506/1425027391.py:3: DtypeWarning: Columns (14,15,16,17,18,19,42,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   financials = pd.read_csv('/Users/dylan/iCollections/桌面文件/jpx-tokyo-stock-exchange-prediction/train_files/financials.csv')
